# %%
#h0 iki grup ortalaması eşittir demek
# reddetme veya reddememeye göre sınarız

#normal dağılım - varyans homojenliği

# p < 0.05 ise h0 red yani ortalamalar eşit değil yani aralarında fark var

# %%
# normallik incelemesi öncesi aykırı değer incelemesi ve düzeltmesi yapmak faydalı olabilir
# normallik sağlanmıyorsa (non-parametrik test) mannwhitneyu
#normallik sağlanıyor varyans homojenliği sağlanmıyorsa t testine parametre girilir
