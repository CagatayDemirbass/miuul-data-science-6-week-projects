# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series([10,77,12,4,5]);s
# Out:
# 0    10
# 1    77
# 2    12
# 3     4
# 4     5
# dtype: int64

# %%
10 in s
# Out:
# False

# %%
10 in s.values
# Out:
# True

# %%
s.values
# Out:
# array([10, 77, 12,  4,  5], dtype=int64)

# %%
s[s>10]
# Out:
# 1    77
# 2    12
# dtype: int64

# %%
import seaborn as sns
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df[0:5]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.iloc[0:5,0:5]
# Out:
#    survived  pclass     sex   age  sibsp
# 0         0       3    male  22.0      1
# 1         1       1  female  38.0      1
# 2         1       3  female  26.0      0
# 3         1       1  female  35.0      1
# 4         0       3    male  35.0      0

# %%
df.loc[0:5,]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
df.drop(0,axis=0)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.set_index("age",drop=True)
# Out:
#       survived  pclass     sex  sibsp  parch     fare embarked   class    who
# age
# 22.0         0       3    male      1      0   7.2500        S   Third    man  \
# 38.0         1       1  female      1      0  71.2833        C   First  woman
# 26.0         1       3  female      0      0   7.9250        S   Third  woman
# 35.0         1       1  female      1      0  53.1000        S   First  woman
# 35.0         0       3    male      0      0   8.0500        S   Third    man
# ...        ...     ...     ...    ...    ...      ...      ...     ...    ...
# 27.0         0       2    male      0      0  13.0000        S  Second    man
# 19.0         1       1  female      0      0  30.0000        S   First  woman
# NaN          0       3  female      1      2  23.4500        S   Third  woman
# 26.0         1       1    male      0      0  30.0000        C   First    man
# 32.0         0       3    male      0      0   7.7500        Q   Third    man
#
# ...

# %%
df.set_index("age",drop=True).reset_index()
# Out:
#       age  survived  pclass     sex  sibsp  parch     fare embarked   class
# 0    22.0         0       3    male      1      0   7.2500        S   Third  \
# 1    38.0         1       1  female      1      0  71.2833        C   First
# 2    26.0         1       3  female      0      0   7.9250        S   Third
# 3    35.0         1       1  female      1      0  53.1000        S   First
# 4    35.0         0       3    male      0      0   8.0500        S   Third
# ..    ...       ...     ...     ...    ...    ...      ...      ...     ...
# 886  27.0         0       2    male      0      0  13.0000        S  Second
# 887  19.0         1       1  female      0      0  30.0000        S   First
# 888   NaN         0       3  female      1      2  23.4500        S   Third
# 889  26.0         1       1    male      0      0  30.0000        C   First
# 890  32.0         0       3    male      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df["age"]**2
# Out:
# 0       484.0
# 1      1444.0
# 2       676.0
# 3      1225.0
# 4      1225.0
#         ...
# 886     729.0
# 887     361.0
# 888       NaN
# 889     676.0
# 890    1024.0
# Name: age, Length: 891, dtype: float64

# %%
df.loc[:,df.columns.str.contains("age")]
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
df.columns.str.contains("age")
# Out:
# array([False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
df.loc[:,~df.columns.str.contains("age")]
# Out:
#      survived  pclass     sex  sibsp  parch     fare embarked   class    who
# 0           0       3    male      1      0   7.2500        S   Third    man  \
# 1           1       1  female      1      0  71.2833        C   First  woman
# 2           1       3  female      0      0   7.9250        S   Third  woman
# 3           1       1  female      1      0  53.1000        S   First  woman
# 4           0       3    male      0      0   8.0500        S   Third    man
# ..        ...     ...     ...    ...    ...      ...      ...     ...    ...
# 886         0       2    male      0      0  13.0000        S  Second    man
# 887         1       1  female      0      0  30.0000        S   First  woman
# 888         0       3  female      1      2  23.4500        S   Third  woman
# 889         1       1    male      0      0  30.0000        C   First    man
# 890         0       3    male      0      0   7.7500        Q   Third    man
#
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[1]
# Out:
# survived               1
# pclass                 1
# sex               female
# age                 38.0
# sibsp                  1
# parch                  0
# fare             71.2833
# embarked               C
# class              First
# who                woman
# adult_male         False
# deck                   C
# embark_town    Cherbourg
# alive                yes
# alone              False
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# survived               1
# pclass                 1
# sex               female
# age                 38.0
# sibsp                  1
# parch                  0
# fare             71.2833
# embarked               C
# class              First
# who                woman
# adult_male         False
# deck                   C
# embark_town    Cherbourg
# alive                yes
# alone              False
# Name: 1, dtype: object

# %%
df.iloc[0:3]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
df.iloc[0:3,0:3]
# Out:
#    survived  pclass     sex
# 0         0       3    male
# 1         1       1  female
# 2         1       3  female

# %%
df.loc[:3,["age","pclass"]]
# Out:
#     age  pclass
# 0  22.0       3
# 1  38.0       1
# 2  26.0       3
# 3  35.0       1

# %%
df[df["pclass"]==2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 9           1       2  female  14.0      1      0  30.0708        C  Second  \
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 17          1       2    male   NaN      0      0  13.0000        S  Second
# 20          0       2    male  35.0      0      0  26.0000        S  Second
# 21          1       2    male  34.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[df["pclass"]==2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 9           1       2  female  14.0      1      0  30.0708        C  Second  \
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 17          1       2    male   NaN      0      0  13.0000        S  Second
# 20          0       2    male  35.0      0      0  26.0000        S  Second
# 21          1       2    male  34.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[df["pclass"]==3,["age","sex"]]
# Out:
#       age     sex
# 0    22.0    male
# 2    26.0  female
# 4    35.0    male
# 5     NaN    male
# 7     2.0    male
# ..    ...     ...
# 882  22.0  female
# 884  25.0    male
# 885  39.0  female
# 888   NaN  female
# 890  32.0    male
#
# [491 rows x 2 columns]

# %%
df.age>50
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
df[df.age>50].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 6          0       1    male  54.0      0      0  51.8625        S   First  \
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 33         0       2    male  66.0      0      0  10.5000        S  Second
# 54         0       1    male  65.0      0      1  61.9792        C   First
#
#       who  adult_male deck  embark_town alive  alone
# 6     man        True    E  Southampton    no   True
# 11  woman       False    C  Southampton   yes   True
# 15  woman       False  NaN  Southampton   yes   True
# 33    man        True  NaN  Southampton    no   True
# 54    man        True    B    Cherbourg    no  False

# %%
df[df.age>50]["age"].count()
# Out:
# 64

# %%
df.loc[df.age>50,"age"].count()
# Out:
# 64

# %%
df.loc[df.age>50,["class","age"]].head()
# Out:
#      class   age
# 6    First  54.0
# 11   First  58.0
# 15  Second  55.0
# 33  Second  66.0
# 54   First  65.0

# %%
df.loc[((df["age"]>50) & (df["sex"]=="female")),["sibsp","pclass","sex"]].head()
# Out:
#      sibsp  pclass     sex
# 11       0       1  female
# 15       0       2  female
# 195      0       1  female
# 268      0       1  female
# 275      1       1  female

# %%
df.loc[(df.age>50) & (df.sex=="male"),["class","age","sex"]].head()
# Out:
#      class   age   sex
# 6    First  54.0  male
# 33  Second  66.0  male
# 54   First  65.0  male
# 94   Third  59.0  male
# 96   First  71.0  male

# %%
df.loc[(df.age>50) & (df.sex=="male") & (df.embark_town=="Southampton"),["class","age","sex","embark_town"]].head()
# Out:
#       class   age   sex  embark_town
# 6     First  54.0  male  Southampton
# 33   Second  66.0  male  Southampton
# 94    Third  59.0  male  Southampton
# 124   First  54.0  male  Southampton
# 150  Second  51.0  male  Southampton

# %%
df.loc[(df.age>50) 
       & (df.sex=="male") 
       & (df.embark_town=="Southampton"),
       ["class","age","sex","embark_town"]].head()
# Out:
#       class   age   sex  embark_town
# 6     First  54.0  male  Southampton
# 33   Second  66.0  male  Southampton
# 94    Third  59.0  male  Southampton
# 124   First  54.0  male  Southampton
# 150  Second  51.0  male  Southampton

# %%
df.loc[(df.age>50) 
       & (df.sex=="male") 
       & ((df.embark_town=="Southampton") | (df.embark_town=="Cherbourg")),
       ["class","age","sex","embark_town"]].head()
# Out:
#      class   age   sex  embark_town
# 6    First  54.0  male  Southampton
# 33  Second  66.0  male  Southampton
# 54   First  65.0  male    Cherbourg
# 94   Third  59.0  male  Southampton
# 96   First  71.0  male    Cherbourg

# %%
df.loc[((df.embark_town=="Southampton") | (df.embark_town=="Cherbourg"))]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[df.embark_town.isin(["Cherbourg","Southampton"])]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[df.deck.isin(["C"])].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1          1       1  female  38.0      1      0   71.2833        C  First
# 3          1       1  female  35.0      1      0   53.1000        S  First
# 11         1       1  female  58.0      0      0   26.5500        S  First
# 27         0       1    male  19.0      3      2  263.0000        S  First
# 55         1       1    male   NaN      0      0   35.5000        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
# 27    man        True    C  Southampton    no  False
# 55    man        True    C  Southampton   yes   True

# %%
df.loc[df.deck.str.contains("C",na=False)].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1          1       1  female  38.0      1      0   71.2833        C  First
# 3          1       1  female  35.0      1      0   53.1000        S  First
# 11         1       1  female  58.0      0      0   26.5500        S  First
# 27         0       1    male  19.0      3      2  263.0000        S  First
# 55         1       1    male   NaN      0      0   35.5000        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
# 27    man        True    C  Southampton    no  False
# 55    man        True    C  Southampton   yes   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.loc[df.embarked.str.contains("C",na=False)].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 19         1       3  female   NaN      0      0   7.2250        C   Third
# 26         0       3    male   NaN      0      0   7.2250        C   Third
# 30         0       1    male  40.0      0      0  27.7208        C   First
#
#       who  adult_male deck embark_town alive  alone
# 1   woman       False    C   Cherbourg   yes  False
# 9   child       False  NaN   Cherbourg   yes  False
# 19  woman       False  NaN   Cherbourg   yes   True
# 26    man        True  NaN   Cherbourg    no   True
# 30    man        True  NaN   Cherbourg    no   True

# %%
df.groupby("sex")[["age"]].mean()
# Out:
#               age
# sex
# female  27.915709
# male    30.726645

# %%
df.groupby("sex").agg({"age":["mean","max"]})
# Out:
#               age
#              mean   max
# sex
# female  27.915709  63.0
# male    30.726645  80.0

# %%
df.groupby("sex").agg({"age":["mean","max"],
                       "survived":"count"})
# Out:
#               age       survived
#              mean   max    count
# sex
# female  27.915709  63.0      314
# male    30.726645  80.0      577

# %%
df.groupby("sex").agg({"age":["mean","max"],
                       "survived":["mean","count"]})
# Out:
#               age        survived
#              mean   max      mean count
# sex
# female  27.915709  63.0  0.742038   314
# male    30.726645  80.0  0.188908   577

# %%
df.groupby(["sex","embark_town"]).agg({"age":["mean","max"],
                       "survived":["mean","count"]})
# Out:
#                           age        survived
#                          mean   max      mean count
# sex    embark_town
# female Cherbourg    28.344262  60.0  0.876712    73
#        Queenstown   24.291667  39.0  0.750000    36
#        Southampton  27.771505  63.0  0.689655   203
# male   Cherbourg    32.998841  71.0  0.305263    95
#        Queenstown   30.937500  70.5  0.073171    41
#        Southampton  30.291440  80.0  0.174603   441

# %%
df2=df.groupby(["sex","embark_town","class"]).agg({"age":["mean","max"],
                       "survived":["mean","count"]});df2
# Out:
#                                  age        survived
#                                 mean   max      mean count
# sex    embark_town class
# female Cherbourg   First   36.052632  60.0  0.976744    43
#                    Second  19.142857  28.0  1.000000     7
#                    Third   14.062500  45.0  0.652174    23
#        Queenstown  First   33.000000  33.0  1.000000     1
#                    Second  30.000000  30.0  1.000000     2
#                    Third   22.850000  39.0  0.727273    33
#        Southampton First   32.704545  63.0  0.958333    48
#                    Second  29.719697  57.0  0.910448    67
#                    Third   23.223684  63.0  0.375000    88
# male   Cherbourg   First   40.111111  71.0  0.404762    42
#                    Second  25.937500  36.0  0.200000    10
#                    Third   25.016800  45.5  0.232558    43
#        Queenstown  First   44.000000  44.0  0.000000     1
#                    Second  57.000000  57.0  0.000000     1
# ...

# %%
df2.loc["male","Southampton",:]
# Out:
#               age        survived
#              mean   max      mean count
# class
# First   41.897188  80.0  0.354430    79
# Second  30.875889  70.0  0.154639    97
# Third   26.574766  74.0  0.128302   265

# %%
df2.loc["female","Cherbourg",:]
# Out:
#               age        survived
#              mean   max      mean count
# class
# First   36.052632  60.0  0.976744    43
# Second  19.142857  28.0  1.000000     7
# Third   14.062500  45.0  0.652174    23

# %%
idx = pd.IndexSlice

# %%
df2.loc[idx["female","Cherbourg"],idx["age","mean"]]
# Out:
# class
# First     36.052632
# Second    19.142857
# Third     14.062500
# Name: (age, mean), dtype: float64

# %%
df.groupby(["sex","embark_town","class"]).agg({"age":["mean"],
                       "survived":["mean","count"],
                       "sex":"count"})
# Out:
#                                  age  survived         sex
#                                 mean      mean count count
# sex    embark_town class
# female Cherbourg   First   36.052632  0.976744    43    43
#                    Second  19.142857  1.000000     7     7
#                    Third   14.062500  0.652174    23    23
#        Queenstown  First   33.000000  1.000000     1     1
#                    Second  30.000000  1.000000     2     2
#                    Third   22.850000  0.727273    33    33
#        Southampton First   32.704545  0.958333    48    48
#                    Second  29.719697  0.910448    67    67
#                    Third   23.223684  0.375000    88    88
# male   Cherbourg   First   40.111111  0.404762    42    42
#                    Second  25.937500  0.200000    10    10
#                    Third   25.016800  0.232558    43    43
#        Queenstown  First   44.000000  0.000000     1     1
# ...

# %%
df.groupby("sex").age.mean()
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
a=df.groupby("sex").agg({"age":["mean","count"]})
a
# Out:
#               age
#              mean count
# sex
# female  27.915709   261
# male    30.726645   453

# %%
a[("age","mean")] / a[("age","count")]
# Out:
# sex
# female    0.106957
# male      0.067829
# dtype: float64

# %%
df.pivot_table(index="sex",values="survived",aggfunc=["mean","count"])
# Out:
#             mean    count
#         survived survived
# sex
# female  0.742038      314
# male    0.188908      577

# %%
df.age.isnull().sum()
# Out:
# 177

# %%
df.groupby("sex").agg({"age":["mean","count"],
                       "sex":["count"]})
# Out:
#               age         sex
#              mean count count
# sex
# female  27.915709   261   314
# male    30.726645   453   577

# %%
df.pivot_table(index="sex",values="age",aggfunc=["mean","count"])
# Out:
#              mean count
#               age   age
# sex
# female  27.915709   261
# male    30.726645   453

# %%
df.pivot_table(values="survived",index="sex",columns=["embarked","class"],aggfunc=["mean"])
# Out:
#               mean
# embarked         C                      Q                          S
# class        First Second     Third First Second     Third     First
# sex
# female    0.976744    1.0  0.652174   1.0    1.0  0.727273  0.958333  \
# male      0.404762    0.2  0.232558   0.0    0.0  0.076923  0.354430
#
#
# embarked
# class       Second     Third
# sex
# female    0.910448  0.375000
# male      0.154639  0.128302

# %%
df["new_age"] = pd.cut(df["age"],[0,10,18,25,40,90],include_lowest=True)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone       new_age
# 0    man        True  NaN  Southampton    no  False  (18.0, 25.0]
# 1  woman       False    C    Cherbourg   yes  False  (25.0, 40.0]
# 2  woman       False  NaN  Southampton   yes   True  (25.0, 40.0]
# 3  woman       False    C  Southampton   yes  False  (25.0, 40.0]
# 4    man        True  NaN  Southampton    no   True  (25.0, 40.0]

# %%
df.pivot_table(index="sex",columns="new_age",values="survived")
# Out:
# new_age  (-0.001, 10.0]  (10.0, 18.0]  (18.0, 25.0]  (25.0, 40.0]  \
# sex
# female         0.612903      0.729730      0.759259      0.802198
# male           0.575758      0.131579      0.120370      0.220930
#
# new_age  (40.0, 90.0]
# sex
# female       0.770833
# male         0.176471

# %%
str(df["new_age"]) + "_" + df["sex"]
# Out:
# 0      0      (18.0, 25.0]\n1      (25.0, 40.0]\n2   ...
# 1      0      (18.0, 25.0]\n1      (25.0, 40.0]\n2   ...
# 2      0      (18.0, 25.0]\n1      (25.0, 40.0]\n2   ...
# 3      0      (18.0, 25.0]\n1      (25.0, 40.0]\n2   ...
# 4      0      (18.0, 25.0]\n1      (25.0, 40.0]\n2   ...
#                              ...
# 886    0      (18.0, 25.0]\n1      (25.0, 40.0]\n2   ...
# 887    0      (18.0, 25.0]\n1      (25.0, 40.0]\n2   ...
# 888    0      (18.0, 25.0]\n1      (25.0, 40.0]\n2   ...
# 889    0      (18.0, 25.0]\n1      (25.0, 40.0]\n2   ...
# 890    0      (18.0, 25.0]\n1      (25.0, 40.0]\n2   ...
# Name: sex, Length: 891, dtype: object

# %%
df["new_age"].astype(str) + "_" + df["sex"]
# Out:
# 0        (18, 25]_male
# 1      (25, 40]_female
# 2      (25, 40]_female
# 3      (25, 40]_female
# 4        (25, 40]_male
#             ...
# 886      (25, 40]_male
# 887    (18, 25]_female
# 888         nan_female
# 889      (25, 40]_male
# 890      (25, 40]_male
# Length: 891, dtype: object

# %%
df.pivot_table(values="survived",index="sex",columns=["new_age"],aggfunc=["mean"])
# Out:
#              mean
# new_age   (0, 10]  (10, 18]  (18, 25]  (25, 40]  (40, 90]
# sex
# female   0.612903  0.729730  0.759259  0.802198  0.770833
# male     0.575758  0.131579  0.120370  0.220930  0.176471

# %%
df.pivot_table(values="survived",columns=["new_age"],aggfunc=["mean"])
# Out:
#              mean
# new_age   (0, 10]  (10, 18]  (18, 25]  (25, 40]  (40, 90]
# survived  0.59375  0.426667  0.333333  0.422053  0.366667

# %%
pd.crosstab(df.new_age,df.survived)
# Out:
# survived    0    1
# new_age
# (0, 10]    26   38
# (10, 18]   43   32
# (18, 25]  108   54
# (25, 40]  152  111
# (40, 90]   95   55

# %%
df["age_gender"] =df['new_age'].astype(str) + "_" + df['sex']

# %%
df.groupby("age_gender").survived.mean()
# Out:
# age_gender
# (0, 10]_female     0.612903
# (0, 10]_male       0.575758
# (10, 18]_female    0.729730
# (10, 18]_male      0.131579
# (18, 25]_female    0.759259
# (18, 25]_male      0.120370
# (25, 40]_female    0.802198
# (25, 40]_male      0.220930
# (40, 90]_female    0.770833
# (40, 90]_male      0.176471
# nan_female         0.679245
# nan_male           0.129032
# Name: survived, dtype: float64

# %%
df.pivot_table(values="survived",index="sex",columns=["class"],aggfunc=["mean"])
# Out:
#             mean
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
df["class"].astype(str) + "_" + df["sex"].astype(str)
# Out:
# 0        Third_male
# 1      First_female
# 2      Third_female
# 3      First_female
# 4        Third_male
#            ...
# 886     Second_male
# 887    First_female
# 888    Third_female
# 889      First_male
# 890      Third_male
# Length: 891, dtype: object

# %%
df.pivot_table(values="survived",columns=["class"],aggfunc=["mean"])
# Out:
#              mean
# class       First    Second     Third
# survived  0.62963  0.472826  0.242363

# %%
df["class_gender"] = df["class"].astype(str) + "_" + df["sex"]

# %%
df.pivot_table(values="survived",columns=["class_gender"],aggfunc=["mean"])
# Out:
#                      mean
# class_gender First_female First_male Second_female Second_male Third_female
# survived         0.968085   0.368852      0.921053    0.157407          0.5  \
#
#
# class_gender Third_male
# survived       0.135447

# %%
df.class_gender.value_counts()
# Out:
# class_gender
# Third_male       347
# Third_female     144
# First_male       122
# Second_male      108
# First_female      94
# Second_female     76
# Name: count, dtype: int64

# %%
pd.crosstab(df.class_gender,df.survived)
# Out:
# survived         0   1
# class_gender
# First_female     3  91
# First_male      77  45
# Second_female    6  70
# Second_male     91  17
# Third_female    72  72
# Third_male     300  47

# %%
df.pivot_table(values="survived",columns=["embark_town"],aggfunc=["mean"])
# Out:
#                  mean
# embark_town Cherbourg Queenstown Southampton
# survived     0.553571    0.38961    0.336957

# %%
df.pivot_table(values="survived",columns=["embark_town"],index="sex",aggfunc=["mean","count"])
# Out:
#                  mean                            count
# embark_town Cherbourg Queenstown Southampton Cherbourg Queenstown Southampton
# sex
# female       0.876712   0.750000    0.689655        73         36         203
# male         0.305263   0.073171    0.174603        95         41         441

# %%
df["embark_town_sex"] =df["embark_town"].astype(str) + "_" + df["sex"]

# %%
df.pivot_table(values="survived",columns="embark_town_sex",aggfunc=["mean"])
# Out:
#                             mean
# embark_town_sex Cherbourg_female Cherbourg_male Queenstown_female
# survived                0.876712       0.305263              0.75  \
#
#
# embark_town_sex Queenstown_male Southampton_female Southampton_male nan_female
# survived               0.073171           0.689655         0.174603        1.0

# %%
df["age2"] = df["age"]*2
df["age3"] = df["age"]*5
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone       new_age  age2   age3
# 0    man        True  NaN  Southampton    no  False  (18.0, 25.0]  44.0  110.0
# 1  woman       False    C    Cherbourg   yes  False  (25.0, 40.0]  76.0  190.0
# 2  woman       False  NaN  Southampton   yes   True  (25.0, 40.0]  52.0  130.0
# 3  woman       False    C  Southampton   yes  False  (25.0, 40.0]  70.0  175.0
# 4    man        True  NaN  Southampton    no   True  (25.0, 40.0]  70.0  175.0

# %%
df.drop(["new_age","age_gender"],axis=1,inplace=True)

# %%
for col in df.columns:
    if "age" in col:
        df[col] = df[col] / 10

# %%
df[["age","age2","age3"]].apply(lambda x:x*2)
# Out:
#      age  age2  age3
# 0    4.4   8.8  22.0
# 1    7.6  15.2  38.0
# 2    5.2  10.4  26.0
# 3    7.0  14.0  35.0
# 4    7.0  14.0  35.0
# ..   ...   ...   ...
# 886  5.4  10.8  27.0
# 887  3.8   7.6  19.0
# 888  NaN   NaN   NaN
# 889  5.2  10.4  26.0
# 890  6.4  12.8  32.0
#
# [891 rows x 3 columns]

# %%
df[["age","age2","age3"]].agg(lambda x:x*2)
# Out:
#      age  age2  age3
# 0    4.4   8.8  22.0
# 1    7.6  15.2  38.0
# 2    5.2  10.4  26.0
# 3    7.0  14.0  35.0
# 4    7.0  14.0  35.0
# ..   ...   ...   ...
# 886  5.4  10.8  27.0
# 887  3.8   7.6  19.0
# 888  NaN   NaN   NaN
# 889  5.2  10.4  26.0
# 890  6.4  12.8  32.0
#
# [891 rows x 3 columns]

# %%
df.loc[:,df.columns.str.contains("age")].apply(lambda x:x*2)
# Out:
#      age  age2  age3
# 0    4.4   8.8  22.0
# 1    7.6  15.2  38.0
# 2    5.2  10.4  26.0
# 3    7.0  14.0  35.0
# 4    7.0  14.0  35.0
# ..   ...   ...   ...
# 886  5.4  10.8  27.0
# 887  3.8   7.6  19.0
# 888  NaN   NaN   NaN
# 889  5.2  10.4  26.0
# 890  6.4  12.8  32.0
#
# [891 rows x 3 columns]

# %%
df.loc[:,df.columns.str.contains("age")].apply(lambda x:x*2)
# Out:
#      age  age2  age3
# 0    4.4   8.8  22.0
# 1    7.6  15.2  38.0
# 2    5.2  10.4  26.0
# 3    7.0  14.0  35.0
# 4    7.0  14.0  35.0
# ..   ...   ...   ...
# 886  5.4  10.8  27.0
# 887  3.8   7.6  19.0
# 888  NaN   NaN   NaN
# 889  5.2  10.4  26.0
# 890  6.4  12.8  32.0
#
# [891 rows x 3 columns]

# %%
df.loc[:,df.columns.str.contains("age")].apply(lambda x:x)
# Out:
#       age       new_age  age2   age3
# 0    22.0  (18.0, 25.0]  44.0  110.0
# 1    38.0  (25.0, 40.0]  76.0  190.0
# 2    26.0  (25.0, 40.0]  52.0  130.0
# 3    35.0  (25.0, 40.0]  70.0  175.0
# 4    35.0  (25.0, 40.0]  70.0  175.0
# ..    ...           ...   ...    ...
# 886  27.0  (25.0, 40.0]  54.0  135.0
# 887  19.0  (18.0, 25.0]  38.0   95.0
# 888   NaN           NaN   NaN    NaN
# 889  26.0  (25.0, 40.0]  52.0  130.0
# 890  32.0  (25.0, 40.0]  64.0  160.0
#
# [891 rows x 4 columns]

# %%
df.loc[:,df.columns.str.contains("age")].apply(lambda x:print(x))
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64
# 0      (18.0, 25.0]
# 1      (25.0, 40.0]
# 2      (25.0, 40.0]
# 3      (25.0, 40.0]
# 4      (25.0, 40.0]
#            ...
# 886    (25.0, 40.0]
# 887    (18.0, 25.0]
# 888             NaN
# 889    (25.0, 40.0]
# 890    (25.0, 40.0]
# Name: new_age, Length: 891, dtype: category
# Categories (5, interval[float64, right]): [(-0.001, 10.0] < (10.0, 18.0] < (18.0, 25.0] < (25.0, 40.0] < (40.0, 90.0]]
# 0      44.0
# 1      76.0
# 2      52.0
# 3      70.0
# 4      70.0
#        ...
# 886    54.0
# 887    38.0
# 888     NaN
# 889    52.0
# 890    64.0
# Name: age2, Length: 891, dtype: float64
# 0      110.0
# 1      190.0
# 2      130.0
# 3      175.0
# 4      175.0
#        ...
# 886    135.0
# 887     95.0
# 888      NaN
# 889    130.0
# 890    160.0
# Name: age3, Length: 891, dtype: float64
# ...

# %%
df.loc[:,df.columns.str.contains("age")].apply(lambda x:x.mean())
# Out:
# age      2.969912
# age2     5.939824
# age3    14.849559
# dtype: float64

# %%
df.loc[:,df.columns.str.contains("age")].apply(lambda x:x-x.mean())
# Out:
#           age      age2      age3
# 0   -0.769912 -1.539824 -3.849559
# 1    0.830088  1.660176  4.150441
# 2   -0.369912 -0.739824 -1.849559
# 3    0.530088  1.060176  2.650441
# 4    0.530088  1.060176  2.650441
# ..        ...       ...       ...
# 886 -0.269912 -0.539824 -1.349559
# 887 -1.069912 -2.139824 -5.349559
# 888       NaN       NaN       NaN
# 889 -0.369912 -0.739824 -1.849559
# 890  0.230088  0.460176  1.150441
#
# [891 rows x 3 columns]

# %%
df.loc[:,df.columns.str.contains("age")].apply(lambda x:x.max())
# Out:
# age      8.0
# age2    16.0
# age3    40.0
# dtype: float64

# %%
def stnd(x):
    return (x-x.mean()) / x.std()

df.loc[:,df.columns.str.contains("age")].apply(stnd)
# Out:
#           age      age2      age3
# 0   -0.530005 -0.530005 -0.530005
# 1    0.571430  0.571430  0.571430
# 2   -0.254646 -0.254646 -0.254646
# 3    0.364911  0.364911  0.364911
# 4    0.364911  0.364911  0.364911
# ..        ...       ...       ...
# 886 -0.185807 -0.185807 -0.185807
# 887 -0.736524 -0.736524 -0.736524
# 888       NaN       NaN       NaN
# 889 -0.254646 -0.254646 -0.254646
# 890  0.158392  0.158392  0.158392
#
# [891 rows x 3 columns]
