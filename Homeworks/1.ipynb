# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.sex.value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
nunique = pd.DataFrame(df.nunique())
nunique.style.background_gradient(cmap="turbo")
# Out:
# <style type="text/css">
# #T_78a89_row0_col0, #T_78a89_row2_col0, #T_78a89_row10_col0, #T_78a89_row13_col0, #T_78a89_row14_col0 {
#   background-color: #30123b;
#   color: #f1f1f1;
# }
# #T_78a89_row1_col0, #T_78a89_row7_col0, #T_78a89_row8_col0, #T_78a89_row9_col0, #T_78a89_row12_col0 {
#   background-color: #321543;
#   color: #f1f1f1;
# }
# #T_78a89_row3_col0 {
#   background-color: #20eaac;
#   color: #000000;
# }
# #T_78a89_row4_col0, #T_78a89_row5_col0, #T_78a89_row11_col0 {
#   background-color: #36215f;
#   color: #f1f1f1;
# }
# #T_78a89_row6_col0 {
#   background-color: #7a0403;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_78a89">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78a89_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78a89_level0_row0" class="row_heading level0 row0" >survived</th>
#       <td id="T_78a89_row0_col0" class="data row0 col0" >2</td>
# ...

# %%
df[["pclass","parch"]].nunique()
# Out:
# pclass    3
# parch     7
# dtype: int64

# %%
df["embarked"].dtypes
# Out:
# dtype('O')

# %%
df["embarked"] = df["embarked"].astype("category")
df["embarked"].dtypes
# Out:
# CategoricalDtype(categories=['C', 'Q', 'S'], ordered=False)

# %%
df["class"].dtype
# Out:
# CategoricalDtype(categories=['First', 'Second', 'Third'], ordered=False)

# %%
df.loc[df["embarked"] =="C"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# 26          0       3    male   NaN      0      0   7.2250        C   Third
# 30          0       1    male  40.0      0      0  27.7208        C   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.loc[df["embarked"].isnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
df.loc[df["embarked"] ==np.nan]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
(df["embarked"] =="C").sum()
# Out:
# 168

# %%
df.loc[~(df["embarked"] =="S")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck embark_town alive  alone
# ...

# %%
df.loc[(df["age"]<30) & (df["sex"]=="female")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df["embark_town"]
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: embark_town, Length: 891, dtype: object

# %%
df.loc[(df["age"]<30) & (df["sex"]=="female") & (df["embark_town"].str.contains("Queenstown",na=False))]
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 22          1       3  female  15.0      0      0  8.0292        Q  Third
# 44          1       3  female  19.0      0      0  7.8792        Q  Third
# 156         1       3  female  16.0      0      0  7.7333        Q  Third
# 208         1       3  female  16.0      0      0  7.7500        Q  Third
# 289         1       3  female  22.0      0      0  7.7500        Q  Third
# 501         0       3  female  21.0      0      0  7.7500        Q  Third
# 654         0       3  female  18.0      0      0  6.7500        Q  Third
#
#        who  adult_male deck embark_town alive  alone
# 22   child       False  NaN  Queenstown   yes   True
# 44   woman       False  NaN  Queenstown   yes   True
# 156  woman       False  NaN  Queenstown   yes   True
# 208  woman       False  NaN  Queenstown   yes   True
# 289  woman       False  NaN  Queenstown   yes   True
# 501  woman       False  NaN  Queenstown    no   True
# ...

# %%
df.loc[(df["age"]<30) & (df["sex"]=="female") & (df["embark_town"].isin(["Queenstown"]))]
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 22          1       3  female  15.0      0      0  8.0292        Q  Third
# 44          1       3  female  19.0      0      0  7.8792        Q  Third
# 156         1       3  female  16.0      0      0  7.7333        Q  Third
# 208         1       3  female  16.0      0      0  7.7500        Q  Third
# 289         1       3  female  22.0      0      0  7.7500        Q  Third
# 501         0       3  female  21.0      0      0  7.7500        Q  Third
# 654         0       3  female  18.0      0      0  6.7500        Q  Third
#
#        who  adult_male deck embark_town alive  alone
# 22   child       False  NaN  Queenstown   yes   True
# 44   woman       False  NaN  Queenstown   yes   True
# 156  woman       False  NaN  Queenstown   yes   True
# 208  woman       False  NaN  Queenstown   yes   True
# 289  woman       False  NaN  Queenstown   yes   True
# 501  woman       False  NaN  Queenstown    no   True
# ...

# %%
df.loc[(df["embark_town"].isin(["Queenstown"]))]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 5           0       3    male   NaN      0      0   8.4583        Q  Third
# 16          0       3    male   2.0      4      1  29.1250        Q  Third
# 22          1       3  female  15.0      0      0   8.0292        Q  Third
# 28          1       3  female   NaN      0      0   7.8792        Q  Third
# 32          1       3  female   NaN      0      0   7.7500        Q  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 790         0       3    male   NaN      0      0   7.7500        Q  Third
# 825         0       3    male   NaN      0      0   6.9500        Q  Third
# 828         1       3    male   NaN      0      0   7.7500        Q  Third
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck embark_town alive  alone
# ...

# %%
df[(df["fare"]>500) & (df["age"]>20)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
#
#        who  adult_male deck embark_town alive  alone
# 258  woman       False  NaN   Cherbourg   yes   True
# 679    man        True    B   Cherbourg   yes  False
# 737    man        True    B   Cherbourg   yes   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df["deck"].fillna(df["deck"].mode().loc[0],inplace=True)

# %%
df["age"].fillna(df["age"].median(),inplace=True)

# %%
df.groupby(["sex","pclass"]).agg({"survived":["mean","count"]})
# Out:
#                survived
#                    mean count
# sex    pclass
# female 1       0.968085    94
#        2       0.921053    76
#        3       0.500000   144
# male   1       0.368852   122
#        2       0.157407   108
#        3       0.135447   347

# %%
X=df.drop("survived",axis=1)
y = df["survived"]

# %%
y.groupby(X["sex"]).mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
df.drop("who",axis=1,inplace=True)

# %%
df["age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df["age_flag"] =df["age"].apply(lambda x: 1 if x<30 else 0)

# %%
def alt(x):
    if x <30:
        return 1
    else:
        return 0
    
df["age"].apply(alt)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 886    1
# 887    1
# 888    1
# 889    1
# 890    0
# Name: age, Length: 891, dtype: int64

# %%
df2 = sns.load_dataset("tips")
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2.groupby("time").agg({"total_bill":["min","mean","max"]})
# Out:
#        total_bill
#               min       mean    max
# time
# Lunch        7.51  17.168676  43.11
# Dinner       3.07  20.797159  50.81

# %%
df2.pivot_table(index="day",values="total_bill",aggfunc=["min","mean","max"])
# Out:
#             min       mean        max
#      total_bill total_bill total_bill
# day
# Thur       7.51  17.682742      43.11
# Fri        5.75  17.151579      40.17
# Sat        3.07  20.441379      50.81
# Sun        7.25  21.410000      48.17

# %%
df2.groupby(["time","sex","day"]).agg({"total_bill":["min","max","mean"]}).loc[:,"Female",:]
# Out:
#             total_bill
#                    min    max       mean
# time   day
# Lunch  Thur       8.35  43.11  16.648710
#        Fri       10.09  16.27  13.940000
#        Sat         NaN    NaN        NaN
#        Sun         NaN    NaN        NaN
# Dinner Thur      18.78  18.78  18.780000
#        Fri        5.75  22.75  14.310000
#        Sat        3.07  44.30  19.680357
#        Sun        9.60  35.26  19.872222

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2.loc[(df2["size"]<3) & (df2["total_bill"] > 10)]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [143 rows x 7 columns]

# %%
df2.loc[(df2["size"]<3) & (df2["total_bill"] > 10),"total_bill"].mean()
# Out:
# 17.184965034965035

# %%
df2["total_bill_tip_sum"] = df2["total_bill"] + df2["tip"]

# %%
df2.sort_values(by="total_bill_tip_sum",ascending=True).iloc[:30]
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_bill_tip_sum
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1                4.07
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2                6.75
# 111        7.25  1.00  Female     No   Sat  Dinner     1                8.25
# 195        7.56  1.44    Male     No  Thur   Lunch     2                9.00
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2                9.18
# 149        7.51  2.00    Male     No  Thur   Lunch     2                9.51
# 135        8.51  1.25  Female     No  Thur   Lunch     2                9.76
# 145        8.35  1.50  Female     No  Thur   Lunch     2                9.85
# 126        8.52  1.48    Male     No  Thur   Lunch     2               10.00
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1               10.50
# 6          8.77  2.00    Male     No   Sun  Dinner     2               10.77
# ...

# %%
df2.nsmallest(30,"total_bill_tip_sum")
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_bill_tip_sum
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1                4.07
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2                6.75
# 111        7.25  1.00  Female     No   Sat  Dinner     1                8.25
# 195        7.56  1.44    Male     No  Thur   Lunch     2                9.00
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2                9.18
# 149        7.51  2.00    Male     No  Thur   Lunch     2                9.51
# 135        8.51  1.25  Female     No  Thur   Lunch     2                9.76
# 145        8.35  1.50  Female     No  Thur   Lunch     2                9.85
# 126        8.52  1.48    Male     No  Thur   Lunch     2               10.00
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1               10.50
# 6          8.77  2.00    Male     No   Sun  Dinner     2               10.77
# ...
